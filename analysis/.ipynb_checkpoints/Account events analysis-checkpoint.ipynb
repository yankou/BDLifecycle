# %%
import pandas as pd
import numpy as np
import scipy as cp
import matplotlib.pyplot as plt
import json
from pprint import pprint
import pymongo
from pymongo import MongoClient
import seaborn as sns

# %%
## load account events data from json
with open('events_output.json') as f:    
    data = json.load(f)

print(data['Aetna'])
# Out:
# {'eventNum': 2, 'events': {'Reping': 6, 'Maybe Later': 58, 'Emailed Re: Session': 0}}

# %%
## load json into mongoDB
client = MongoClient('localhost', 27017)
db = client.mydb
posts = db.events
for ele in data:
    posts.insert(data[ele])

# %%
## Plot distribution of events per account
# %matplotlib inline
eventNum = [(data[x]['eventNum']) for x in data]
# print(eventNum)

sns.set(color_codes=True)
ax = sns.distplot(eventNum, bins=3, kde=False, rug=False)
ax.set(xlim=(0, 2), xticks=[0,1,2])
ax.set_xlabel('BD events', fontsize=14)

# %%
import operator
events=[[x,data[x]['events']] for x in data if data[x]['eventNum']>0]

def orderEvents(eventDict):
    sorted_events = sorted(eventDict.items(), key=operator.itemgetter(1))
    return sorted_events

test = [{x[0]:orderEvents(x[1])} for x in events]
print(len(test))
# test
# Out:
# 45

# %%
## load account events data from json
import datetime
with open('status_matrix_output.json') as f:    
    data = json.load(f)
exp = data['Aetna']
# t = datetime.datetime.strptime('2017-02-08', '%Y-%m-%d').date()

collabel = [x[0] for x in exp]
row = list(data.keys())
df = pd.DataFrame(0, index=row, columns=collabel)
df.head(5)
# Out:
#                             2017-02-08  2017-02-09  2017-02-10  2017-02-11  \
# City of Boston                       0           0           0           0
# Behavior Health Innovators           0           0           0           0
# ThriveHive                           0           0           0           0
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        0           0           0           0
#
#                             2017-02-12  2017-02-13  2017-02-14  2017-02-15  \
# City of Boston                       0           0           0           0
# Behavior Health Innovators           0           0           0           0
# ThriveHive                           0           0           0           0
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        0           0           0           0
#
#                             2017-02-16  2017-02-17     ...      2017-04-08  \
# City of Boston                       0           0     ...               0
# Behavior Health Innovators           0           0     ...               0
# ThriveHive                           0           0     ...               0
# The D. E. Shaw Group                 0           0     ...               0
# Epidemico Inc                        0           0     ...               0
#
#                             2017-04-09  2017-04-10  2017-04-11  2017-04-12  \
# City of Boston                       0           0           0           0
# Behavior Health Innovators           0           0           0           0
# ThriveHive                           0           0           0           0
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        0           0           0           0
#
#                             2017-04-13  2017-04-14  2017-04-15  2017-04-16  \
# City of Boston                       0           0           0           0
# Behavior Health Innovators           0           0           0           0
# ThriveHive                           0           0           0           0
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        0           0           0           0
#
#                             2017-04-17
# City of Boston                       0
# Behavior Health Innovators           0
# ThriveHive                           0
# The D. E. Shaw Group                 0
# Epidemico Inc                        0
#
# [5 rows x 68 columns]

# %%
data

# for key, value in all_accounts.iteritems()
for key, value in data.items():
    if len(value) == len(collabel):
        df.loc[key] = [x[1] for x in value]
#         print(df.loc[key])
    else:
        for ele in value:
            df.loc[key][ele[0]] = ele[1]
df.head(5)
# Out:
#                             2017-02-08  2017-02-09  2017-02-10  2017-02-11  \
# City of Boston                       2           2           2           2
# Behavior Health Innovators           2           2           2           2
# ThriveHive                           1           1           1           1
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        2           2           2           2
#
#                             2017-02-12  2017-02-13  2017-02-14  2017-02-15  \
# City of Boston                       2           2           2           2
# Behavior Health Innovators           2           2           2           2
# ThriveHive                           1           1           2           2
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        2           2           2           2
#
#                             2017-02-16  2017-02-17     ...      2017-04-08  \
# City of Boston                       2           2     ...               2
# Behavior Health Innovators           2           2     ...               2
# ThriveHive                           2           2     ...               2
# The D. E. Shaw Group                 0           0     ...               0
# Epidemico Inc                        2           2     ...               2
#
#                             2017-04-09  2017-04-10  2017-04-11  2017-04-12  \
# City of Boston                       2           2           2           2
# Behavior Health Innovators           2           2           2           2
# ThriveHive                           2           2           2           2
# The D. E. Shaw Group                 0           0           0           0
# Epidemico Inc                        2           2           2           2
#
#                             2017-04-13  2017-04-14  2017-04-15  2017-04-16  \
# City of Boston                       2           2           2           2
# Behavior Health Innovators           2           2           2           2
# ThriveHive                           2           2           2           2
# The D. E. Shaw Group                 0           6           6           6
# Epidemico Inc                        2           2           2           2
#
#                             2017-04-17
# City of Boston                       2
# Behavior Health Innovators           2
# ThriveHive                           2
# The D. E. Shaw Group                 6
# Epidemico Inc                        2
#
# [5 rows x 68 columns]

# %%
plt.figure(figsize=(20,20))

sns.heatmap(df, linewidths=.2, cmap="YlGnBu")  #cmap="YlGnBu", 
# plt.figure(figsize=(20, 20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-d0caa7b69da0> in <module>()
#       1 plt.figure(figsize=(20,20))
#       2
# ----> 3 sns.heatmap(df, linewidths=.2, cmap=sns.color_palette("Paired",as_cmap=True))  #cmap="YlGnBu",
#       4 # plt.figure(figsize=(20, 20))
#       5
#
# TypeError: color_palette() got an unexpected keyword argument 'as_cmap'
